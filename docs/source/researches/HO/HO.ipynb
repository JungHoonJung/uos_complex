# %% [markdown]
# # Higher-Order Interaction

# %% [markdown]
# **Contributors** : Jung-Hoon Jung

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ## Test plot

# %%
plt.plot(np.linspace(-1,1,100), np.linspace(-1,1,100)**2)
